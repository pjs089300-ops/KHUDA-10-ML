# %% [markdown]
# <a href="https://colab.research.google.com/github/pjs089300-ops/KHUDA-10-ML/blob/main/Untitled9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('hello world')
# Out:
# hello world
